# %% [markdown]
# # 01 — PaySim and Base Data Analysis
#
# Inspect either the downloaded PaySim CSV or the repository-generated fallback. This notebook does not train a model.
#
# Run from the repository root with the project virtual environment selected.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.data.load_paysim import load_paysim
from src.settings import get_settings
settings = get_settings()
df = load_paysim(settings.paysim_csv, n_rows=5000, seed=settings.random_seed)
df.head()

# %%
df.shape, df['base_type'].value_counts(), df['base_is_fraud'].value_counts()

# %%
df[['amount']].describe(percentiles=[.5,.9,.95,.99])
