# %% [markdown]
# # 07 — Heterogeneous Graph Transformer
#
# Train relation-aware HGT snapshot encoders for each graph view.
#
# Run from the repository root with the project virtual environment selected.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.graph.build_views import build_and_save_all_views
paths = build_and_save_all_views(features.head(5000), 'data/graph_views/notebook')
paths

# %%
from src.models.hgt_model import train_hgt_view
result = train_hgt_view(paths['money'], 'models/graph/notebook_hgt', view_name='money', epochs=2)
result.scores.head()
