# %% [markdown]
# # 09 — Fusion, Policy and Evaluation
#
# Run or inspect the complete trainer, then evaluate edge cases and final actions.
#
# Run from the repository root with the project virtual environment selected.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Full command (run from a terminal):
# python -m src.training.train_all --skip-prepare
from pathlib import Path
Path('models/metrics.json').read_text() if Path('models/metrics.json').exists() else 'Train models first.'

# %%
import pandas as pd
scored = pd.read_pickle('data/processed/scored_transactions.pkl') if Path('data/processed/scored_transactions.pkl').exists() else pd.DataFrame()
scored[['scenario','final_fraud_probability','uncertainty','recommended_action']].groupby('scenario').agg(['mean','count']) if not scored.empty else scored

# %%
# Complete report:
# python -m src.training.evaluate
