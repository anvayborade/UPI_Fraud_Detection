# %% [markdown]
# # 02 — UPI Scenario and Hard-Negative Generation
#
# Inject UPI-specific context, social-engineering scenarios, mule patterns and legitimate edge cases.
#
# Run from the repository root with the project virtual environment selected.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.simulation.generate_scenarios import inject_upi_scenarios
upi = inject_upi_scenarios(df, seed=42)
upi[['scenario','is_fraud','is_legitimate_novelty','payment_mode','recipient_archetype']].head()

# %%
upi['scenario'].value_counts()

# %%
upi.groupby('scenario')[['amount','distance_from_usual_km','rapid_outflow_ratio','recipient_complaint_score']].mean().round(2)
