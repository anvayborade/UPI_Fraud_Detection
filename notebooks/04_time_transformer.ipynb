# %% [markdown]
# # 04 — Time-Aware Sequence Transformer
#
# Generate app/session journeys and train the compact Transformer that predicts account takeover and social-engineering journey risk.
#
# Run from the repository root with the project virtual environment selected.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from src.simulation.generate_sequences import generate_event_sequences
events = generate_event_sequences(features.head(3000), Path('data/sequences/notebook_events.parquet'), seed=42)
events.head(12)

# %%
events.groupby('transaction_id')['event_type'].apply(list).head()

# %%
from src.models.time_transformer import train_time_transformer, score_sequences
bundle = train_time_transformer(events, 'models/sequence_notebook', epochs=2)
scores = score_sequences(bundle, events)
scores.head()
