# %% [markdown]
# # 05 — Heterogeneous Graph Construction
#
# Build the three graph views and inspect node and edge types.
#
# Run from the repository root with the project virtual environment selected.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.graph.build_views import build_all_views
views = build_all_views(features.head(5000))
list(views)

# %%
for name, data in views.items():
    print(name, data.metadata())
    print({node_type: data[node_type].num_nodes for node_type in data.node_types})

# %%
from src.graph.schema import GRAPH_VIEW_DESCRIPTIONS
GRAPH_VIEW_DESCRIPTIONS
